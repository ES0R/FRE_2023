# %%
## Imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import cv2 as cv

# %%
# 
positive_fig = "picture\positive"
negative_fig = "picture\negative"

print(positive_fig+"\deer1.jpg")


im = cv.imread(positive_fig+"/deer1.jpg")
im = im[:, :, ::-1]
im = im.astype(float).mean(2) / 255

plt.figure()
plt.imshow(im, cmap='gray')
# Out:
# picture\positive\deer1.jpg
